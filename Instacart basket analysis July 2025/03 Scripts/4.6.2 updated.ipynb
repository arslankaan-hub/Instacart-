# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import databases
path = r'C:\Users\arsla\Instacart basket analysis July 2025\02 Data'

# %%
# Import dataframe

orders_products_combined_checked = pd.read_pickle(os.path.join(path,'prepared data' , 'orders_products_combined_checked.pkl'))

df_prods = pd.read_csv(os.path.join(path, 'prepared data' , 'products_doublechecked.csv'), index_col = 0)

# %%
# Check the shape of the imported dataframe

orders_products_combined_checked.shape
# Out:
# (32434489, 10)

# %%
orders_products_combined_checked.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     7.0         196                  1          0   both
# 1                     7.0       14084                  2          0   both
# 2                     7.0       12427                  3          0   both
# 3                     7.0       26088                  4          0   both
# 4                     7.0       26405                  5          0   both

# %%
df_prods.shape
# Out:
# (49672, 5)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# test merge without overwriting with merge flag 'match'

pd.merge(orders_products_combined_checked , df_prods , on = ['product_id'] , how = 'inner', indicator = 'match' )
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32404854   2977660   206209            13                   1
# 32404855   2977660   206209            13                   1
# 32404856   2977660   206209            13                   1
# 32404857   2977660   206209            13                   1
# 32404858   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     7.0         196
# 1                         8                     7.0       14084
# ...

# %%
# actual merge of 'orders_products_combined' and '_df_pords'

ords_prods_merge = orders_products_combined_checked.merge(df_prods , on = ['product_id'] , indicator = 'match' )

# %%
# drop the flag column '_merge' from the previous merge

ords_prods_merge.drop('_merge', axis = 1 )
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32404854   2977660   206209            13                   1
# 32404855   2977660   206209            13                   1
# 32404856   2977660   206209            13                   1
# 32404857   2977660   206209            13                   1
# 32404858   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     7.0         196
# 1                         8                     7.0       14084
# ...

# %%
#exporting dataframe as pickle
ords_prods_merge.to_pickle(os.path.join(path, 'Prepared data' ,'ords_prods_merge_checked.pkl'))
