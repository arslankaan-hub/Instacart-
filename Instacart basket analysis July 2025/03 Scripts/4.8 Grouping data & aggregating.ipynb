# %% [markdown]
# # Exercise/Achievement 4.8
# # Kaan Arslan

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import databases
path = r'C:\Users\arsla\Instacart basket analysis July 2025\02 Data'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path,'Prepared Data','ords_prods_merged_after_exercise.7.pkl'))

# %%
#limit the database 
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     7.0         196                  1          0   both
# 1                     7.0       14084                  2          0   both
# 2                     7.0       12427                  3          0   both
# 3                     7.0       26088                  4          0   both
# 4                     7.0       26405                  5          0   both
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
#
#   match    price_range_loc     busiest day  busiest days busiest_period_of_day
# 0  both  Mid-range product  Regularly busy  Regular days        Average orders
# 1  both  Mid-range product  Regularly busy  Regular days        Average orders
# 2  both  Low-range product  Regularly busy  Regular days        Average orders
# 3  both  Low-range product  Regularly busy  Regular days        Average orders
# 4  both  Low-range product  Regularly busy  Regular days        Average orders

# %%
df.groupby('product_name')

# %%
#aggregation exercise
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                      1.0
# 2                      1.0
# 3                      1.0
# 4                      1.0
# 5                      1.0
# 6                      1.0
# 7                      1.0
# 8                      1.0
# 9                      1.0
# 10                     1.0
# 11                     1.0
# 12                     1.0
# 13                     1.0
# 14                     1.0
# 15                     1.0
# 16                     1.0
# 17                     1.0
# 18                     1.0
# 19                     1.0
# 20                     1.0
# 21                     1.0

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                      1.0
# 2                      1.0
# 3                      1.0
# 4                      1.0
# 5                      1.0
# 6                      1.0
# 7                      1.0
# 8                      1.0
# 9                      1.0
# 10                     1.0
# 11                     1.0
# 12                     1.0
# 13                     1.0
# 14                     1.0
# 15                     1.0
# 16                     1.0
# 17                     1.0
# 18                     1.0
# 19                     1.0
# 20                     1.0
# 21                     1.0

# %% [markdown]
# ### I'm confused about why all are equal to 1

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     1.0
# 7     1.0
# 8     1.0
# 9     1.0
# 10    1.0
# 11    1.0
# 12    1.0
# 13    1.0
# 14    1.0
# 15    1.0
# 16    1.0
# 17    1.0
# 18    1.0
# 19    1.0
# 20    1.0
# 21    1.0
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     1.0
# 7     1.0
# 8     1.0
# 9     1.0
# 10    1.0
# 11    1.0
# 12    1.0
# 13    1.0
# 14    1.0
# 15    1.0
# 16    1.0
# 17    1.0
# 18    1.0
# 19    1.0
# 20    1.0
# 21    1.0
# Name: order_number, dtype: float64

# %%
#performing multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                      1.0   1   1
# 2                      1.0   1   1
# 3                      1.0   1   1
# 4                      1.0   1   1
# 5                      1.0   1   1
# 6                      1.0   1   1
# 7                      1.0   1   1
# 8                      1.0   1   1
# 9                      1.0   1   1
# 10                     1.0   1   1
# 11                     1.0   1   1
# 12                     1.0   1   1
# 13                     1.0   1   1
# 14                     1.0   1   1
# 15                     1.0   1   1
# 16                     1.0   1   1
# 17                     1.0   1   1
# 18                     1.0   1   1
# 19                     1.0   1   1
# 20                     1.0   1   1
# 21                     1.0   1   1

# %%
ords_prods_merge.head(30)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2168274        2             1                   2                 11
# 6    2168274        2             1                   2                 11
# 7    2168274        2             1                   2                 11
# 8    2168274        2             1                   2                 11
# 9    2168274        2             1                   2                 11
# 10   2168274        2             1                   2                 11
# 11   2168274        2             1                   2                 11
# 12   2168274        2             1                   2                 11
# 13   2168274        2             1                   2                 11
# 14   2168274        2             1                   2                 11
# 15   2168274        2             1                   2                 11
# 16   2168274        2             1                   2                 11
# 17   2168274        2             1                   2                 11
# 18   1374495        3             1                   1                 14
# 19   1374495        3             1                   1                 14
# 20   1374495        3             1                   1                 14
# 21   1374495        3             1                   1                 14
# 22   1374495        3             1                   1                 14
# 23   1374495        3             1                   1                 14
# 24   1374495        3             1                   1                 14
# 25   1374495        3             1                   1                 14
# 26   1374495        3             1                   1                 14
# 27   1374495        3             1                   1                 14
# 28   3343014        4             1                   6                 11
# 29   3343014        4             1                   6                 11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      7.0         196                  1          0   both
# 1                      7.0       14084                  2          0   both
# 2                      7.0       12427                  3          0   both
# 3                      7.0       26088                  4          0   both
# 4                      7.0       26405                  5          0   both
# 5                      7.0       32792                  1          0   both
# 6                      7.0       47766                  2          0   both
# 7                      7.0       20574                  3          0   both
# 8                      7.0       12000                  4          0   both
# 9                      7.0       48110                  5          0   both
# 10                     7.0       22474                  6          0   both
# 11                     7.0       16589                  7          0   both
# 12                     7.0       35917                  8          0   both
# 13                     7.0       27344                  9          0   both
# 14                     7.0       30489                 10          0   both
# 15                     7.0       27966                 11          0   both
# 16                     7.0       13176                 12          0   both
# 17                     7.0       45066                 13          0   both
# 18                     7.0        9387                  1          0   both
# 19                     7.0       17668                  2          0   both
# 20                     7.0       15143                  3          0   both
# 21                     7.0       16797                  4          0   both
# 22                     7.0       39190                  5          0   both
# 23                     7.0       47766                  6          0   both
# 24                     7.0       21903                  7          0   both
# 25                     7.0       39922                  8          0   both
# 26                     7.0       24810                  9          0   both
# 27                     7.0       32402                 10          0   both
# 28                     7.0       36606                  1          0   both
# 29                     7.0        7350                  2          0   both
#
#                                        product_name  aisle_id  department_id  \
# 0                                              Soda        77              7
# 1           Organic Unsweetened Vanilla Almond Milk        91             16
# 2                               Original Beef Jerky        23             19
# 3                        Aged White Cheddar Popcorn        23             19
# 4                  XL Pick-A-Size Paper Towel Rolls        54             17
# 5                    Chipotle Beef & Pork Realstick        23             19
# 6                                   Organic Avocado        24              4
# 7                                    Roasted Turkey        96             20
# 8          Baked Organic Sea Salt Crunchy Pea Snack        72             13
# 9           Thin Stackers Brown Rice Lightly Salted        78             19
# 10                   Cheddar Bunnies Snack Crackers        78             19
# 11                                   Plantain Chips       107             19
# 12                 Organic Just Concord Grape Juice        98              7
# 13                             Uncured Genoa Salami        96             20
# 14                                  Original Hummus        67             20
# 15                              Organic Raspberries       123              4
# 16                           Bag of Organic Bananas        24              4
# 17                                 Honeycrisp Apple        24              4
# 18                              Granny Smith Apples        24              4
# 19  Unsweetened Chocolate Almond Breeze Almond Milk        91             16
# 20                                   Blueberry Pint        24              4
# 21                                     Strawberries        24              4
# 22                  Vanilla Unsweetened Almond Milk        91             16
# 23                                  Organic Avocado        24              4
# 24                             Organic Baby Spinach       123              4
# 25                                    Celery Sticks       123              4
# 26          Organic Lightly Salted Brown Rice Cakes        78             19
# 27                        Crackers, Crispy, Cheddar        78             19
# 28                       Sprouted Multi-Grain Bread       112              3
# 29      Natural Lime Flavor Sparkling Mineral Water       115              7
#
#     prices match    price_range_loc     busiest day  busiest days  \
# 0      9.0  both  Mid-range product  Regularly busy  Regular days
# 1     12.5  both  Mid-range product  Regularly busy  Regular days
# 2      4.4  both  Low-range product  Regularly busy  Regular days
# 3      4.7  both  Low-range product  Regularly busy  Regular days
# 4      1.0  both  Low-range product  Regularly busy  Regular days
# 5      5.2  both  Mid-range product  Regularly busy  Regular days
# 6      6.3  both  Mid-range product  Regularly busy  Regular days
# 7      2.3  both  Low-range product  Regularly busy  Regular days
# 8     10.9  both  Mid-range product  Regularly busy  Regular days
# 9      2.7  both  Low-range product  Regularly busy  Regular days
# 10     4.1  both  Low-range product  Regularly busy  Regular days
# 11     5.0  both  Low-range product  Regularly busy  Regular days
# 12     9.4  both  Mid-range product  Regularly busy  Regular days
# 13    14.8  both  Mid-range product  Regularly busy  Regular days
# 14     7.5  both  Mid-range product  Regularly busy  Regular days
# 15     4.4  both  Low-range product  Regularly busy  Regular days
# 16    10.3  both  Mid-range product  Regularly busy  Regular days
# 17     2.5  both  Low-range product  Regularly busy  Regular days
# 18     8.8  both  Mid-range product  Regularly busy  Busiest days
# 19     6.6  both  Mid-range product  Regularly busy  Busiest days
# 20     6.0  both  Mid-range product  Regularly busy  Busiest days
# 21     1.3  both  Low-range product  Regularly busy  Busiest days
# 22    12.3  both  Mid-range product  Regularly busy  Busiest days
# 23     6.3  both  Mid-range product  Regularly busy  Busiest days
# 24     8.2  both  Mid-range product  Regularly busy  Busiest days
# 25    14.4  both  Mid-range product  Regularly busy  Busiest days
# 26     5.8  both  Mid-range product  Regularly busy  Busiest days
# 27     4.1  both  Low-range product  Regularly busy  Busiest days
# 28     9.4  both  Mid-range product  Regularly busy  Regular days
# 29     7.0  both  Mid-range product  Regularly busy  Regular days
#
#    busiest_period_of_day
# 0         Average orders
# 1         Average orders
# 2         Average orders
# 3         Average orders
# 4         Average orders
# 5            Most orders
# 6            Most orders
# 7            Most orders
# 8            Most orders
# 9            Most orders
# 10           Most orders
# 11           Most orders
# 12           Most orders
# 13           Most orders
# 14           Most orders
# 15           Most orders
# 16           Most orders
# 17           Most orders
# 18           Most orders
# 19           Most orders
# 20           Most orders
# 21           Most orders
# 22           Most orders
# 23           Most orders
# 24           Most orders
# 25           Most orders
# 26           Most orders
# 27           Most orders
# 28           Most orders
# 29           Most orders

# %%
ords_prods_merge.tail(30)
# Out:
#          order_id  user_id  order_number  orders_day_of_week  \
# 2076066   2166133   206207             1                   6
# 2076067   2166133   206207             1                   6
# 2076068   2166133   206207             1                   6
# 2076069   2166133   206207             1                   6
# 2076070   2166133   206207             1                   6
# 2076071   2227043   206208             1                   1
# 2076072   2227043   206208             1                   1
# 2076073   2227043   206208             1                   1
# 2076074   2227043   206208             1                   1
# 2076075   2227043   206208             1                   1
# 2076076   2227043   206208             1                   1
# 2076077   2227043   206208             1                   1
# 2076078   2227043   206208             1                   1
# 2076079   2227043   206208             1                   1
# 2076080   2227043   206208             1                   1
# 2076081   2227043   206208             1                   1
# 2076082   2227043   206208             1                   1
# 2076083   3154581   206209             1                   3
# 2076084   3154581   206209             1                   3
# 2076085   3154581   206209             1                   3
# 2076086   3154581   206209             1                   3
# 2076087   3154581   206209             1                   3
# 2076088   3154581   206209             1                   3
# 2076089   3154581   206209             1                   3
# 2076090   3154581   206209             1                   3
# 2076091   3154581   206209             1                   3
# 2076092   3154581   206209             1                   3
# 2076093   3154581   206209             1                   3
# 2076094   3154581   206209             1                   3
# 2076095   3154581   206209             1                   3
#
#          order_hour_of_day  days_since_prior_order  product_id  \
# 2076066                 19                     7.0       33806
# 2076067                 19                     7.0        5165
# 2076068                 19                     7.0       14332
# 2076069                 19                     7.0       39619
# 2076070                 19                     7.0        2954
# 2076071                 15                     7.0       34213
# 2076072                 15                     7.0       27966
# 2076073                 15                     7.0       33000
# 2076074                 15                     7.0       23579
# 2076075                 15                     7.0       27845
# 2076076                 15                     7.0       20995
# 2076077                 15                     7.0       43086
# 2076078                 15                     7.0       47766
# 2076079                 15                     7.0       40706
# 2076080                 15                     7.0       14467
# 2076081                 15                     7.0       44910
# 2076082                 15                     7.0         165
# 2076083                 11                     7.0        6846
# 2076084                 11                     7.0        9405
# 2076085                 11                     7.0       41213
# 2076086                 11                     7.0       40396
# 2076087                 11                     7.0       14901
# 2076088                 11                     7.0       40534
# 2076089                 11                     7.0       23039
# 2076090                 11                     7.0         890
# 2076091                 11                     7.0       20073
# 2076092                 11                     7.0       13176
# 2076093                 11                     7.0       20842
# 2076094                 11                     7.0       23594
# 2076095                 11                     7.0       25837
#
#          add_to_cart_order  reordered _merge  \
# 2076066                 20          0   both
# 2076067                 21          0   both
# 2076068                 22          0   both
# 2076069                 23          0   both
# 2076070                 24          0   both
# 2076071                  1          0   both
# 2076072                  2          0   both
# 2076073                  3          0   both
# 2076074                  4          0   both
# 2076075                  5          0   both
# 2076076                  6          0   both
# 2076077                  7          0   both
# 2076078                  8          0   both
# 2076079                  9          0   both
# 2076080                 10          0   both
# 2076081                 11          0   both
# 2076082                 12          0   both
# 2076083                  1          0   both
# 2076084                  2          0   both
# 2076085                  3          0   both
# 2076086                  4          0   both
# 2076087                  5          0   both
# 2076088                  6          0   both
# 2076089                  7          0   both
# 2076090                  8          0   both
# 2076091                  9          0   both
# 2076092                 10          0   both
# 2076093                 11          0   both
# 2076094                 12          0   both
# 2076095                 13          0   both
#
#                                               product_name  aisle_id  \
# 2076066                               Flax Seed Crispbread        78
# 2076067            Organic Basil Garlic Polenta Pre-Cooked        63
# 2076068                             Organic Yellow Mustard        72
# 2076069                   Organic Tomato Basil Pasta Sauce         9
# 2076070  Organic Diced Fire Roasted No Salt Added Tomatoes        81
# 2076071                                  Great White Bread       112
# 2076072                                Organic Raspberries       123
# 2076073                                  Pure Irish Butter        36
# 2076074  Peanut Butter Chocolate Chip Fruit & Nut Food Bar         3
# 2076075                                 Organic Whole Milk        84
# 2076076                           Organic Broccoli Florets       116
# 2076077                                 Super Greens Salad       123
# 2076078                                    Organic Avocado        24
# 2076079                             Organic Grape Tomatoes       123
# 2076080                                     Sweet Baguette       112
# 2076081                           Organic Spring Mix Salad       123
# 2076082                  Wild Chanterelle Mushroom Ravioli        12
# 2076083                                    Diet Pepsi Pack        77
# 2076084   Calcium Enriched 100% Lactose Free Fat Free Milk        91
# 2076085                                        French Loaf       112
# 2076086                                          Guacamole        67
# 2076087                                            Raisins       117
# 2076088              In Rich Tomato Sauce Vegetarian Beans        59
# 2076089                              Fat Free Cream Cheese       108
# 2076090                             Organic Diced Tomatoes        81
# 2076091                                         Jazz Apple        24
# 2076092                             Bag of Organic Bananas        24
# 2076093                              Total 0% Greek Yogurt       120
# 2076094                                       Medium Salsa        51
# 2076095           Mini Babybel Light Semisoft Edam Cheeses        21
#
#          department_id  prices match    price_range_loc     busiest day  \
# 2076066             19     2.8  both  Low-range product  Regularly busy
# 2076067              9     7.8  both  Mid-range product  Regularly busy
# 2076068             13     3.7  both  Low-range product  Regularly busy
# 2076069              9     3.3  both  Low-range product  Regularly busy
# 2076070             15     2.5  both  Low-range product  Regularly busy
# 2076071              3    12.7  both  Mid-range product  Regularly busy
# 2076072              4     4.4  both  Low-range product  Regularly busy
# 2076073             16    12.2  both  Mid-range product  Regularly busy
# 2076074             19     1.7  both  Low-range product  Regularly busy
# 2076075             16    12.8  both  Mid-range product  Regularly busy
# 2076076              1     8.3  both  Mid-range product  Regularly busy
# 2076077              4     8.0  both  Mid-range product  Regularly busy
# 2076078              4     6.3  both  Mid-range product  Regularly busy
# 2076079              4     8.6  both  Mid-range product  Regularly busy
# 2076080              3     4.5  both  Low-range product  Regularly busy
# 2076081              4     9.5  both  Mid-range product  Regularly busy
# 2076082              9     2.4  both  Low-range product  Regularly busy
# 2076083              7    11.3  both  Mid-range product  Regularly busy
# 2076084             16    11.5  both  Mid-range product  Regularly busy
# 2076085              3     4.8  both  Low-range product  Regularly busy
# 2076086             20     3.6  both  Low-range product  Regularly busy
# 2076087             19     2.0  both  Low-range product  Regularly busy
# 2076088             15    13.3  both  Mid-range product  Regularly busy
# 2076089             16     3.4  both  Low-range product  Regularly busy
# 2076090             15     4.9  both  Low-range product  Regularly busy
# 2076091              4     6.4  both  Mid-range product  Regularly busy
# 2076092              4    10.3  both  Mid-range product  Regularly busy
# 2076093             16    13.6  both  Mid-range product  Regularly busy
# 2076094             13     3.7  both  Low-range product  Regularly busy
# 2076095             16     3.8  both  Low-range product  Regularly busy
#
#          busiest days busiest_period_of_day
# 2076066  Regular days        Average orders
# 2076067  Regular days        Average orders
# 2076068  Regular days        Average orders
# 2076069  Regular days        Average orders
# 2076070  Regular days        Average orders
# 2076071  Busiest days           Most orders
# 2076072  Busiest days           Most orders
# 2076073  Busiest days           Most orders
# 2076074  Busiest days           Most orders
# 2076075  Busiest days           Most orders
# 2076076  Busiest days           Most orders
# 2076077  Busiest days           Most orders
# 2076078  Busiest days           Most orders
# 2076079  Busiest days           Most orders
# 2076080  Busiest days           Most orders
# 2076081  Busiest days           Most orders
# 2076082  Busiest days           Most orders
# 2076083  Slowest days           Most orders
# 2076084  Slowest days           Most orders
# 2076085  Slowest days           Most orders
# 2076086  Slowest days           Most orders
# 2076087  Slowest days           Most orders
# 2076088  Slowest days           Most orders
# 2076089  Slowest days           Most orders
# 2076090  Slowest days           Most orders
# 2076091  Slowest days           Most orders
# 2076092  Slowest days           Most orders
# 2076093  Slowest days           Most orders
# 2076094  Slowest days           Most orders
# 2076095  Slowest days           Most orders

# %%
#aggregating with transform
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform('max')

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2168274        2             1                   2                 11
# 6    2168274        2             1                   2                 11
# 7    2168274        2             1                   2                 11
# 8    2168274        2             1                   2                 11
# 9    2168274        2             1                   2                 11
# 10   2168274        2             1                   2                 11
# 11   2168274        2             1                   2                 11
# 12   2168274        2             1                   2                 11
# 13   2168274        2             1                   2                 11
# 14   2168274        2             1                   2                 11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      7.0         196                  1          0   both
# 1                      7.0       14084                  2          0   both
# 2                      7.0       12427                  3          0   both
# 3                      7.0       26088                  4          0   both
# 4                      7.0       26405                  5          0   both
# 5                      7.0       32792                  1          0   both
# 6                      7.0       47766                  2          0   both
# 7                      7.0       20574                  3          0   both
# 8                      7.0       12000                  4          0   both
# 9                      7.0       48110                  5          0   both
# 10                     7.0       22474                  6          0   both
# 11                     7.0       16589                  7          0   both
# 12                     7.0       35917                  8          0   both
# 13                     7.0       27344                  9          0   both
# 14                     7.0       30489                 10          0   both
#
#                                 product_name  aisle_id  department_id  prices  \
# 0                                       Soda        77              7     9.0
# 1    Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                        Original Beef Jerky        23             19     4.4
# 3                 Aged White Cheddar Popcorn        23             19     4.7
# 4           XL Pick-A-Size Paper Towel Rolls        54             17     1.0
# 5             Chipotle Beef & Pork Realstick        23             19     5.2
# 6                            Organic Avocado        24              4     6.3
# 7                             Roasted Turkey        96             20     2.3
# 8   Baked Organic Sea Salt Crunchy Pea Snack        72             13    10.9
# 9    Thin Stackers Brown Rice Lightly Salted        78             19     2.7
# 10            Cheddar Bunnies Snack Crackers        78             19     4.1
# 11                            Plantain Chips       107             19     5.0
# 12          Organic Just Concord Grape Juice        98              7     9.4
# 13                      Uncured Genoa Salami        96             20    14.8
# 14                           Original Hummus        67             20     7.5
#
#    match    price_range_loc     busiest day  busiest days  \
# 0   both  Mid-range product  Regularly busy  Regular days
# 1   both  Mid-range product  Regularly busy  Regular days
# 2   both  Low-range product  Regularly busy  Regular days
# 3   both  Low-range product  Regularly busy  Regular days
# 4   both  Low-range product  Regularly busy  Regular days
# 5   both  Mid-range product  Regularly busy  Regular days
# 6   both  Mid-range product  Regularly busy  Regular days
# 7   both  Low-range product  Regularly busy  Regular days
# 8   both  Mid-range product  Regularly busy  Regular days
# 9   both  Low-range product  Regularly busy  Regular days
# 10  both  Low-range product  Regularly busy  Regular days
# 11  both  Low-range product  Regularly busy  Regular days
# 12  both  Mid-range product  Regularly busy  Regular days
# 13  both  Mid-range product  Regularly busy  Regular days
# 14  both  Mid-range product  Regularly busy  Regular days
#
#    busiest_period_of_day  max_order
# 0         Average orders          1
# 1         Average orders          1
# 2         Average orders          1
# 3         Average orders          1
# 4         Average orders          1
# 5            Most orders          1
# 6            Most orders          1
# 7            Most orders          1
# 8            Most orders          1
# 9            Most orders          1
# 10           Most orders          1
# 11           Most orders          1
# 12           Most orders          1
# 13           Most orders          1
# 14           Most orders          1

# %%
#creating a 'loyalty flag' with loc
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# New customer    2076096
# Name: count, dtype: int64

# %%
#checking the output
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id  loyalty_flag  order_number
# 0         1  New customer             1
# 1         1  New customer             1
# 2         1  New customer             1
# 3         1  New customer             1
# 4         1  New customer             1
# 5         2  New customer             1
# 6         2  New customer             1
# 7         2  New customer             1
# 8         2  New customer             1
# 9         2  New customer             1
# 10        2  New customer             1
# 11        2  New customer             1
# 12        2  New customer             1
# 13        2  New customer             1
# 14        2  New customer             1
# 15        2  New customer             1
# 16        2  New customer             1
# 17        2  New customer             1
# 18        3  New customer             1
# 19        3  New customer             1
# 20        3  New customer             1
# 21        3  New customer             1
# 22        3  New customer             1
# 23        3  New customer             1
# 24        3  New customer             1
# 25        3  New customer             1
# 26        3  New customer             1
# 27        3  New customer             1
# 28        4  New customer             1
# 29        4  New customer             1
# 30        4  New customer             1
# 31        4  New customer             1
# 32        5  New customer             1
# 33        5  New customer             1
# 34        5  New customer             1
# 35        5  New customer             1
# 36        5  New customer             1
# 37        5  New customer             1
# 38        5  New customer             1
# 39        5  New customer             1
# 40        5  New customer             1
# 41        5  New customer             1
# 42        5  New customer             1
# 43        6  New customer             1
# 44        6  New customer             1
# 45        6  New customer             1
# 46        6  New customer             1
# 47        7  New customer             1
# 48        7  New customer             1
# 49        7  New customer             1
# 50        7  New customer             1
# 51        7  New customer             1
# 52        7  New customer             1
# 53        7  New customer             1
# 54        7  New customer             1
# 55        7  New customer             1
# 56        7  New customer             1
# 57        7  New customer             1
# 58        7  New customer             1
# 59        8  New customer             1

# %% [markdown]
# ##Q5 of the task

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                  prices
#                    mean  min      max
# loyalty_flag
# New customer  12.023704  1.0  99999.0

# %%
# Aggregating Data with transform
ords_prods_merge['avg_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform('mean')

# %%
ords_prods_merge[['user_id', 'avg_product_price']].head(30)
# Out:
#     user_id  avg_product_price
# 0         1           6.320000
# 1         1           6.320000
# 2         1           6.320000
# 3         1           6.320000
# 4         1           6.320000
# 5         2           6.569231
# 6         2           6.569231
# 7         2           6.569231
# 8         2           6.569231
# 9         2           6.569231
# 10        2           6.569231
# 11        2           6.569231
# 12        2           6.569231
# 13        2           6.569231
# 14        2           6.569231
# 15        2           6.569231
# 16        2           6.569231
# 17        2           6.569231
# 18        3           7.380000
# 19        3           7.380000
# 20        3           7.380000
# 21        3           7.380000
# 22        3           7.380000
# 23        3           7.380000
# 24        3           7.380000
# 25        3           7.380000
# 26        3           7.380000
# 27        3           7.380000
# 28        4          10.300000
# 29        4          10.300000

# %% [markdown]
# ### Q6 of the task

# %%
# Creating a 'Spending Flag' with loc
ords_prods_merge.loc[ords_prods_merge['avg_product_price'] >= 10, 'spending_flag'] = 'High spender'
ords_prods_merge.loc[ords_prods_merge['avg_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
#checking the result
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     1966543
# High spender     109553
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'avg_product_price', 'spending_flag']].head(20)
# Out:
#     user_id  avg_product_price spending_flag
# 0         1           6.320000   Low spender
# 1         1           6.320000   Low spender
# 2         1           6.320000   Low spender
# 3         1           6.320000   Low spender
# 4         1           6.320000   Low spender
# 5         2           6.569231   Low spender
# 6         2           6.569231   Low spender
# 7         2           6.569231   Low spender
# 8         2           6.569231   Low spender
# 9         2           6.569231   Low spender
# 10        2           6.569231   Low spender
# 11        2           6.569231   Low spender
# 12        2           6.569231   Low spender
# 13        2           6.569231   Low spender
# 14        2           6.569231   Low spender
# 15        2           6.569231   Low spender
# 16        2           6.569231   Low spender
# 17        2           6.569231   Low spender
# 18        3           7.380000   Low spender
# 19        3           7.380000   Low spender

# %% [markdown]
# #### Q7 of the task

# %%
#aggregating data with transform
ords_prods_merge['median_days_between_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform('median')

# %%
#checking the result
ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders']].head(20)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders
# 0         1                     7.0                         7.0
# 1         1                     7.0                         7.0
# 2         1                     7.0                         7.0
# 3         1                     7.0                         7.0
# 4         1                     7.0                         7.0
# 5         2                     7.0                         7.0
# 6         2                     7.0                         7.0
# 7         2                     7.0                         7.0
# 8         2                     7.0                         7.0
# 9         2                     7.0                         7.0
# 10        2                     7.0                         7.0
# 11        2                     7.0                         7.0
# 12        2                     7.0                         7.0
# 13        2                     7.0                         7.0
# 14        2                     7.0                         7.0
# 15        2                     7.0                         7.0
# 16        2                     7.0                         7.0
# 17        2                     7.0                         7.0
# 18        3                     7.0                         7.0
# 19        3                     7.0                         7.0

# %%
# Creating a 'Frequency Flag' using loc 
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['median_days_between_orders'] <= 20) & (ords_prods_merge['median_days_between_orders'] > 10), 'order_frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer    2076096
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders', 'order_frequency_flag']].head(10)
# Out:
#    user_id  days_since_prior_order  median_days_between_orders  \
# 0        1                     7.0                         7.0
# 1        1                     7.0                         7.0
# 2        1                     7.0                         7.0
# 3        1                     7.0                         7.0
# 4        1                     7.0                         7.0
# 5        2                     7.0                         7.0
# 6        2                     7.0                         7.0
# 7        2                     7.0                         7.0
# 8        2                     7.0                         7.0
# 9        2                     7.0                         7.0
#
#   order_frequency_flag
# 0    Frequent customer
# 1    Frequent customer
# 2    Frequent customer
# 3    Frequent customer
# 4    Frequent customer
# 5    Frequent customer
# 6    Frequent customer
# 7    Frequent customer
# 8    Frequent customer
# 9    Frequent customer

# %%
ords_prods_merge.to_pickle(os.path.join(path,'Prepared Data', 'ords_prods_merged_grouped_Task8.pkl'))
